# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Mursawal
# - **Email:** mursyawal29@gmail.com
# - **ID Dicoding:** mursawal201

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Jenis penilaian apa yang paling sering diberikan customer terhadap produk?
# - Jenis pembayaran apa yang paling sering digunakan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ###Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
custumers_df = pd.read_csv('/content/customers_dataset.csv')
custumers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('/content/geolocation_dataset.csv')
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
orders_items_df = pd.read_csv('/content/order_items_dataset.csv')
orders_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv('/content/order_payments_dataset.csv')
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_review_df = pd.read_csv('/content/order_reviews_dataset.csv')
order_review_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_dataset_df = pd.read_csv('/content/orders_dataset.csv')
order_dataset_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_df = pd.read_csv('/content/product_category_name_translation.csv')
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_dataset_df = pd.read_csv('/content/products_dataset.csv')
product_dataset_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
seller_dataset_df = pd.read_csv('/content/sellers_dataset.csv')
seller_dataset_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Pada tahap ini kita mengumpulkan semua data yang ada dengan mengubahnya menjadi dataframe

# %% [markdown]
# ### Assessing Data

# %%
custumers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 71721  92e16dc77c3bc26f219eedd465b6d189  3f00548d480f59bdac5e1ad8a68dcfe1
# 11548  ff886777efd58cd30781969d96dfe558  f063eaa15d17c4e9322323850377ca21
# 91004  a0d1571c3090051864507fd978cf138c  c49b3a5af585dd2635f11bb8ac77e292
# 93542  dbfe964127abbea0522a3f5e10f3781f  43a8a00e071b8d2962fc44a682ed3d4e
# 35938  ca9f4ec6bcaa553e20c64a99a2da7d66  53aa526509baa27abd29887973326ec4
#
#        customer_zip_code_prefix   customer_city customer_state
# 71721                     27916           macae             RJ
# 11548                     13426      piracicaba             SP
# 91004                     17550  julio mesquita             SP
# 93542                      5835       sao paulo             SP
# 35938                     88801        criciuma             SC

# %%
custumers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
custumers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
custumers_df.duplicated().sum()
# Out:
# 0

# %%
geolocation_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 884411                        86050       -23.335250       -51.164728
# 794648                        73813       -15.549047       -47.327386
# 138404                         5684       -23.608440       -46.707799
# 441099                        22011       -22.961994       -43.175991
# 308762                        13480       -22.561356       -47.404936
#
#        geolocation_city geolocation_state
# 884411         londrina                PR
# 794648          formosa                GO
# 138404        sao paulo                SP
# 441099   rio de janeiro                RJ
# 308762          limeira                SP

# %%
geolocation_df.info()
geolocation_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# ...

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geolocation_df.drop_duplicates(inplace=True)
geolocation_df.duplicated().sum()
# Out:
# 0

# %%
orders_items_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 91657  cff47646caf0e301a4622b80cc415cb9              1
# 17551  283a7afd444a9a463b7bc938f0344f70              1
# 44394  64e32e79cb2d36bb6c9848e16fba6029              1
# 27264  3e08aa33483ffe505b5de4748dc70c7f              2
# 56746  81161411335afb1d9c6dfd1b42a63eb3              1
#
#                              product_id                         seller_id  \
# 91657  f282b8032570cf3ce692b8ea7e1b6c53  e8b4225284fbb02d16f200513f1f395d
# 17551  027cdd14a677a5834bc67a9789db5021  620c87c171fb2a6dd6e8bb4dec959fc6
# 44394  83d5757d175fa2b1b90e5369ce549b8e  d1b65fc7debc3361ea86b5f14c68d2e2
# 27264  1a405418406359cc2b8815f93bf359c2  4d6d651bd7684af3fffabd5f08d12e5a
# 56746  5f24a2c5fe04fac8072d899fffa77540  23a0ffca143a15b9b5bbdb7d552f626a
#
#        shipping_limit_date   price  freight_value
# 91657  2018-04-19 13:15:10  149.90          23.63
# 17551  2017-06-29 02:05:07  139.90          15.73
# ...

# %%
orders_items_df.info()
orders_items_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# ...

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  orders_items_df[column] = pd.to_datetime(orders_items_df[column])

# %%
ints_columns = ["price", "freight_value"]

for column in ints_columns:
    orders_items_df[column] = orders_items_df[column].astype(float)

# %%
orders_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
orders_items_df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_payments_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 48670  2bbf04c7da16334276d95e3f4b7b938d                   1  credit_card
# 41493  9cca82f566f14878d871fcf5cd0125e3                   1       boleto
# 73875  c4d5588c1ee36814fc302422334e67f5                   2      voucher
# 81593  4c33f92b62a822db77b38b88bc7ad237                   2      voucher
# 13025  bff8a4fd45acacd3f3390aed67ed8e91                   1  credit_card
#
#        payment_installments  payment_value
# 48670                     1         208.20
# 41493                     1         162.64
# 73875                     1         250.00
# 81593                     1          19.07
# 13025                     1          28.86

# %%
order_payments_df.info()
order_payments_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# ...

# %%
order_review_df.sample(5)
# Out:
#                               review_id                          order_id  \
# 88693  58db1fb83ed38cc529964e1e57405854  1be26189c5971cf28b268e3ab43b3a6f
# 30861  a6c2242648d5b750b739de1dcaa5f42e  f24afd66659f204e2fe3866ae39f4e20
# 59196  2c6c22e94f53c3b5153705fcfb2b58a1  9e4e44e1a6c68a8d59b97d5e6c241974
# 95981  5b3e6a4905490b42830a938b0943ee88  1b3d11cf9f92c0f7baf627ab059621f8
# 38499  f1ad116b3cd3a668471e641bece92f7f  0030ff924c38549807645976adeef2c0
#
#        review_score review_comment_title  \
# 88693             5                  NaN
# 30861             4                  NaN
# 59196             1                  NaN
# 95981             5                  NaN
# 38499             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 88693                                                NaN  2017-07-22 00:00:00
# 30861                                                NaN  2018-07-26 00:00:00
# ...

# %%
order_review_df.info()
order_review_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
order_dataset_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 63739  e9e2effacedebc11741ec26027686fe9  eeb35afbdf6ec4f7409b604d5ef4dfd4
# 65974  f1ba1af891ddd14899ba97155589732f  c55f7aac91e0605d8f8333211949bd5e
# 75593  121dbde7d88c82adc886e26b28552ef7  e9d4a08d748f76bdddafcbbbaf1e9fc9
# 63958  135873f19ffdd8c0841b7e7b7c45220c  c80dacf7bf207169171e7c16acacf880
# 31430  509b86c65fe4e2ad5b96408cfef9755e  69f07139131eb94ecb8e5b5d601b1f7a
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 63739    delivered      2017-03-01 08:47:36  2017-03-01 09:02:21
# 65974    delivered      2017-08-21 00:27:44  2017-08-21 00:44:36
# 75593    delivered      2018-05-19 16:13:18  2018-05-19 16:32:07
# 63958    delivered      2018-07-19 07:21:17  2018-07-19 07:30:08
# 31430    delivered      2018-01-31 23:37:38  2018-02-02 16:00:30
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
order_dataset_df.info()
order_dataset_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# ...

# %%
product_category_df.info()
product_category_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
product_dataset_df.sample(5)
# Out:
#                              product_id   product_category_name  \
# 3643   3625fbaf8284047185fb0351f2f84ae3           esporte_lazer
# 19255  8d56572e0e7f9f3c82d73c8ebe61623e        malas_acessorios
# 31188  12087840651e83b48206b82c213b76fd           esporte_lazer
# 32346  c3b957b4e1d4cd8d595794d22973cae9                   bebes
# 7210   6a09d996beaebffe169f70c614ac2485  informatica_acessorios
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 3643                  55.0                       815.0                 4.0
# 19255                 28.0                       360.0                 1.0
# 31188                 27.0                       521.0                 1.0
# 32346                 46.0                       309.0                 4.0
# 7210                  57.0                       317.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 3643             1600.0               25.0                8.0
# ...

# %%
product_dataset_df.info()
product_dataset_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# ...

# %%
seller_dataset_df.info()
seller_dataset_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
# - Dari data yang telah didapatkan ada beberapa data yang tidak sesuai dengan tipe datanya

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Data custumers

# %%
custumers_df.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
custumers_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data Geolocation

# %%
geolocation_df.duplicated().sum()
# Out:
# 0

# %%
geolocation_df.drop_duplicates(inplace=True)
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data Orders Items

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  orders_items_df[column] = pd.to_datetime(orders_items_df[column])

# %%
ints_columns = ["price", "freight_value"]

for column in ints_columns:
    orders_items_df[column] = orders_items_df[column].astype(float)

# %%
orders_items_df.duplicated().sum()
# Out:
# 0

# %%
orders_items_df.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Data Order Payment

# %%
order_payments_df.duplicated().sum()
# Out:
# 0

# %%
order_payments_df.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# Data Order Reviews

# %%
order_review_df.duplicated().sum()
# Out:
# 0

# %%
order_review_df.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_review_df['review_comment_title'].fillna('No Title Available', inplace=True)
order_review_df['review_comment_message'].fillna('No Comment Message Provided', inplace=True)

# %%
order_review_df.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
datetime_columns = ["review_creation_date","review_answer_timestamp"]

for column in datetime_columns:
  order_review_df[column] = pd.to_datetime(order_review_df[column])

# %%
order_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# Data Datasets

# %%
order_dataset_df.duplicated().sum()
# Out:
# 0

# %%
order_dataset_df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order_dataset_df.dropna(inplace=True)

# %%
order_dataset_df.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
datetime_columns = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime_columns:
  order_dataset_df[column] = pd.to_datetime(order_dataset_df[column])

# %%
order_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96461 non-null  object
#  1   customer_id                    96461 non-null  object
#  2   order_status                   96461 non-null  object
#  3   order_purchase_timestamp       96461 non-null  datetime64[ns]
#  4   order_approved_at              96461 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   96461 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96461 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  96461 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.6+ MB

# %% [markdown]
# Data Produk kategori

# %%
product_category_df.duplicated().sum()
# Out:
# 0

# %%
product_category_df.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# Data Produk Dataset

# %%
product_dataset_df.duplicated().sum()
# Out:
# 0

# %%
product_dataset_df.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_dataset_df['product_category_name'].fillna('No Product Category Name Available ', inplace=True)

# %%
product_dataset_df.dropna(inplace=True)

# %%
product_dataset_df.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
product_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# Data Seller Dataset

# %%
seller_dataset_df.duplicated().sum()
# Out:
# 0

# %%
seller_dataset_df.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
seller_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# **Insight:**
# - Ada beberapa yang data duplikat maka dilakukan penghapusan atau drop data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
custumers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
orders_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
custumers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
produk_df = pd.merge(
    left=orders_items_df,
    right=product_dataset_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
produk_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1 2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
produk_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  9417
# beleza_saude                     8836
# esporte_lazer                    7720
# informatica_acessorios           6689
# moveis_decoracao                 6449
#                                  ...
# la_cuisine                         13
# cds_dvds_musicais                  12
# pc_gamer                            8
# fashion_roupa_infanto_juvenil       8
# seguros_e_servicos                  2
# Name: order_id, Length: 73, dtype: int64

# %%
orderz_df = pd.merge(
    left=orders_items_df,
    right=order_dataset_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orderz_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  \
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
final_df = pd.merge(
    left=produk_df,
    right=orderz_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
final_df.head()
# Out:
#                            order_id  order_item_id_x  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                1
# 1  00018f77f2f0320c557190d7a144bdd3                1
# 2  000229ec398224ef6ca0657da4fc703e                1
# 3  00024acbcdf0a6daa1e931b038114c75                1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                1
#
#                        product_id_x                       seller_id_x  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date_x  price_x  freight_value_x product_category_name  \
# 0   2017-09-19 09:45:35    58.90            13.29            cool_stuff
# 1   2017-05-03 11:05:13   239.90            19.93              pet_shop
# ...

# %%
final_df.groupby(by="product_category_name").order_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  9417
# beleza_saude                     8836
# esporte_lazer                    7720
# informatica_acessorios           6689
# moveis_decoracao                 6449
#                                  ...
# la_cuisine                         13
# cds_dvds_musicais                  12
# pc_gamer                            8
# fashion_roupa_infanto_juvenil       8
# seguros_e_servicos                  2
# Name: order_id, Length: 73, dtype: int64

# %%
final_df.groupby(by="product_category_name").agg({
    "product_id_x": "nunique",
    "price_x":  "sum"
})
# Out:
#                            product_id_x    price_x
# product_category_name
# agro_industria_e_comercio            74  110333.05
# alimentos                            82   36582.11
# alimentos_bebidas                   104   20309.47
# artes                                55   26391.92
# artes_e_artesanato                   19    1904.70
# ...                                 ...        ...
# sinalizacao_e_seguranca              93   48454.93
# tablets_impressao_imagem              9    8492.91
# telefonia                          1134  396672.76
# telefonia_fixa                      116  198239.57
# utilidades_domesticas              2335  870489.99
#
# [73 rows x 2 columns]

# %%
finalx_df = pd.merge(
    left=final_df,
    right=custumers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
finalx_df.head()
# Out:
#                            order_id  order_item_id_x  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                1
# 1  00018f77f2f0320c557190d7a144bdd3                1
# 2  000229ec398224ef6ca0657da4fc703e                1
# 3  00024acbcdf0a6daa1e931b038114c75                1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                1
#
#                        product_id_x                       seller_id_x  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date_x  price_x  freight_value_x product_category_name  \
# 0   2017-09-19 09:45:35    58.90            13.29            cool_stuff
# 1   2017-05-03 11:05:13   239.90            19.93              pet_shop
# ...

# %%
finalx_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered    96455
# canceled         6
# Name: order_id, dtype: int64

# %%
finalx_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157222 entries, 0 to 157221
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       157222 non-null  object
#  1   order_item_id_x                157222 non-null  int64
#  2   product_id_x                   157222 non-null  object
#  3   seller_id_x                    157222 non-null  object
#  4   shipping_limit_date_x          157222 non-null  datetime64[ns]
#  5   price_x                        157222 non-null  float64
#  6   freight_value_x                157222 non-null  float64
#  7   product_category_name          155057 non-null  object
#  8   product_name_lenght            155057 non-null  float64
#  9   product_description_lenght     155057 non-null  float64
#  10  product_photos_qty             155057 non-null  float64
#  11  product_weight_g               155057 non-null  float64
# ...

# %%
finalY_df = pd.merge(
    left=order_payments_df,
    right=orderz_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
finalY_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value  order_item_id  \
# 0                     8          99.33            1.0
# 1                     1          24.39            1.0
# 2                     1          65.71            1.0
# 3                     8         107.78            1.0
# 4                     2         128.45            1.0
#
#                          product_id                         seller_id  \
# 0  af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 1  a630cc320a8c872f9de830cf121661a3  eaf6d55068dea77334e8477d3878d89e
# ...

# %%
final1_df = pd.merge(
    left=finalx_df,
    right=finalY_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
final1_df.head()
# Out:
#                            order_id  order_item_id_x  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                1
# 1  00018f77f2f0320c557190d7a144bdd3                1
# 2  000229ec398224ef6ca0657da4fc703e                1
# 3  00024acbcdf0a6daa1e931b038114c75                1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                1
#
#                        product_id_x                       seller_id_x  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date_x  price_x  freight_value_x product_category_name  \
# 0   2017-09-19 09:45:35    58.90            13.29            cool_stuff
# 1   2017-05-03 11:05:13   239.90            19.93              pet_shop
# ...

# %%
final1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372004 entries, 0 to 372003
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   order_id                         372004 non-null  object
#  1   order_item_id_x                  372004 non-null  int64
#  2   product_id_x                     372004 non-null  object
#  3   seller_id_x                      372004 non-null  object
#  4   shipping_limit_date_x            372004 non-null  datetime64[ns]
#  5   price_x                          372004 non-null  float64
#  6   freight_value_x                  372004 non-null  float64
#  7   product_category_name            367530 non-null  object
#  8   product_name_lenght              367530 non-null  float64
#  9   product_description_lenght       367530 non-null  float64
#  10  product_photos_qty               367530 non-null  float64
# ...

# %%
finalY_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
order_review_df["review_category"] = order_review_df.review_score.apply(
    lambda x: "Very Poor" if x == 1 else
               ("Poor" if x == 2 else
               ("Average" if x == 3 else
               ("Good" if x == 4 else "Excellent")))
)
order_review_df.groupby(by="review_score").order_id.nunique().sort_values(ascending=False)
# Out:
# review_score
# 5    57076
# 4    19098
# 1    11393
# 3     8160
# 2     3148
# Name: order_id, dtype: int64

# %%
finalm_df = pd.merge(
    left=order_review_df,
    right=finalY_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
finalm_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4   No Title Available            No Comment Message Provided
# 1             4   No Title Available            No Comment Message Provided
# 2             5   No Title Available            No Comment Message Provided
# 3             5   No Title Available            No Comment Message Provided
# 4             5   No Title Available  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp review_category  \
# ...

# %%
finalm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118144 entries, 0 to 118143
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   review_id                      118144 non-null  object
#  1   order_id                       118144 non-null  object
#  2   review_score                   118144 non-null  int64
#  3   review_comment_title           118144 non-null  object
#  4   review_comment_message         118144 non-null  object
#  5   review_creation_date           118144 non-null  datetime64[ns]
#  6   review_answer_timestamp        118144 non-null  datetime64[ns]
#  7   review_category                118144 non-null  object
#  8   payment_sequential             118143 non-null  float64
#  9   payment_type                   118143 non-null  object
#  10  payment_installments           118143 non-null  float64
# ...

# %%
finalm_df.groupby(by="review_category").agg({
    "order_id": "nunique",
})
# Out:
#                  order_id
# review_category
# Average              8160
# Excellent           57076
# Good                19098
# Poor                 3148
# Very Poor           11393

# %%
finalm_df.to_csv('main.csv', index=False)

print("File CSV telah berhasil disimpan.")
# Out:
# File CSV telah berhasil disimpan.

# %% [markdown]
# **Insight:**
# - Kita telah mendapatkan beberapa data yang dibutuhkan dengan cara menggabungkan beberapa dataframe dan menyortirnya untuk menjawab setiap pertanyaan bisnis kita

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bystatez_df = finalm_df.groupby(by="review_category").order_id.nunique().reset_index()
bystatez_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="review_category",
    y="order_id",
    data=bystatez_df.sort_values(by="order_id", ascending=False),
    palette=colors_
)
plt.title("Penilaian terhadap barang yang di order", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-202-4a738178a9dc>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-202-4a738178a9dc>:5: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Pertanyaan 2:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bystate_df = finalY_df.groupby(by="payment_type").order_id.nunique().reset_index()
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="order_id",
    y="payment_type",
    data=bystate_df.sort_values(by="order_id", ascending=False),
    palette=colors_
)
plt.title("Jenis Pembayaran yang paling sering dilakukan", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-204-e80457ce3b4c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-204-e80457ce3b4c>:5: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   sns.barplot(

# %% [markdown]
# **Insight:**
# - Dari visualisasi yang dilakukan untuk penilaian terhadap barang yang diorder kebanyakan excelent atau paling baik

# %%
# Mengelompokkan data untuk mendapatkan metrik RFM
rfm_df = finalm_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max",  # Mengambil tanggal order terakhir
    "order_id": "nunique",               # Menghitung jumlah order
    "price": "sum"                       # Menghitung jumlah revenue yang dihasilkan
})

# Mengubah nama kolom
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# Menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = pd.to_datetime(rfm_df["max_order_timestamp"]).dt.date  # Pastikan ini dalam format tanggal
recent_date = rfm_df["max_order_timestamp"].max()  # Menggunakan rfm_df untuk mendapatkan tanggal terakhir
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

# Menghapus kolom 'max_order_timestamp' jika tidak diperlukan
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)

# Menampilkan hasil
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1     89.80      288
# 1  000161a058600d5901f007fab4c27140          1     54.90      409
# 2  0001fd6190edaaf884bcaf3d49edf079          1    179.99      547
# 3  0002414f95344307404f0ace7a26f1d5          1    149.90      378
# 4  000379cdec625522490c315e70c7a9fb          1     93.00      149

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(3), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=8)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(3), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=8)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(3), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=8)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# <ipython-input-206-30bf5409e330>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(3), palette=colors, ax=ax[0])
# <ipython-input-206-30bf5409e330>:5: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(3), palette=colors, ax=ax[0])
# <ipython-input-206-30bf5409e330>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(3), palette=colors, ax=ax[1])
# ...

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Dari visualisasi yang telah dilakukan jenis penilaian yang paling banyak terhadap barang yang diorder adalah excelent atau baik
# - Dari visualisasi yang telah dilakukan kebanyakan customer menggunakan type pembayaran credit_card sendangkan yang paling sedikit ialah debit card dan not_defined
